# %% [markdown]
# # Polynomial Regression with Linear Model
#
# If our data is actually more complex than a simple straight line, a linear model will fit it badly, if we want our model to fit properly, we can add a feature in the dataset which will simply be our X values squared.
# Let's see how to do that.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

np.random.seed(42)

# %% [markdown]
# We start by generating a dataset.

# %%
X = 6 * np.random.rand(200, 1) - 3
y = 0.5 * X**3 + X/2 + np.random.randn(200, 1)

fig = plt.figure(figsize=(8,6))
plt.scatter(X, y)
plt.title("Dataset")
plt.xlabel("Independant Variable")
plt.ylabel("Dependant Variable")
plt.show()

# %%
X.shape
# Out:
# (200, 1)

# %% [markdown]
# Now we need to add a feature to our data.
# New feature = $\large X_i^n$, **n** being the square value from our function.

# %%
X_poly = np.append(X, X**3, 1)
print(X_poly[0:5])
# Out:
# [[ -2.19550115 -10.58281014]
#  [ -1.84156636  -6.24542672]
#  [  2.82591991  22.5672972 ]
#  [  0.29684688   0.02615757]
#  [ -1.90498666  -6.91314741]]

# %% [markdown]
# We'll use the Normal Equation. Because it's short.

# %%
def normal_equation(X, y):
    theta = np.linalg.inv(X.T @ X) @ (X.T @ y) # @ operator = Dot product
    return theta

theta = normal_equation(X_poly, y)
print(theta)
# Out:
# [[0.52432816]
#  [0.50311901]]

# %%
predict_test = X_poly @ theta

# %%
fig = plt.figure(figsize=(8,6))
plt.title('Dataset')
plt.scatter(X, y)
plt.xlabel("Independant Variable")
plt.ylabel("Dependant Variable")
plt.scatter(X, predict_test, color='red')
plt.show()
